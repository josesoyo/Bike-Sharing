# %% [markdown]
# # Bike sharing for tree regression
#
# - [My tests]()
#     - [Data preprocessing](#Data-Preprocesing)
#     - [Data Dropped](#Drop-some-data-correlated-among-them)
#     - [Lineal model](#Lineal-model)
#     - [SVM model](#SVM-prediction)
# - [Tree model](Tree-model-with-sklearn)

# %%
import pandas as pd
import numpy as np
import matplotlib.pylab as plt
import seaborn as sns

# %matplotlib inline

# %% [markdown]
# # Data Preprocesing
#
# I will check how the data behaves and see if there are high correlations among variables
# - Comment: No outlayers work
#
# The variable to predict is: __cnt__

# %%
dataset = pd.read_csv("day.csv")

dataset.describe()
# Out:
#           instant      season          yr        mnth     holiday     weekday  \
# count  731.000000  731.000000  731.000000  731.000000  731.000000  731.000000
# mean   366.000000    2.496580    0.500684    6.519836    0.028728    2.997264
# std    211.165812    1.110807    0.500342    3.451913    0.167155    2.004787
# min      1.000000    1.000000    0.000000    1.000000    0.000000    0.000000
# 25%    183.500000    2.000000    0.000000    4.000000    0.000000    1.000000
# 50%    366.000000    3.000000    1.000000    7.000000    0.000000    3.000000
# 75%    548.500000    3.000000    1.000000   10.000000    0.000000    5.000000
# max    731.000000    4.000000    1.000000   12.000000    1.000000    6.000000
#
#        workingday  weathersit        temp       atemp         hum   windspeed  \
# count  731.000000  731.000000  731.000000  731.000000  731.000000  731.000000
# mean     0.683995    1.395349    0.495385    0.474354    0.627894    0.190486
# std      0.465233    0.544894    0.183051    0.162961    0.142429    0.077498
# min      0.000000    1.000000    0.059130    0.079070    0.000000    0.022392
# 25%      0.000000    1.000000    0.337083    0.337842    0.520000    0.134950
# 50%      1.000000    1.000000    0.498333    0.486733    0.626667    0.180975
# 75%      1.000000    2.000000    0.655417    0.608602    0.730209    0.233214
# max      1.000000    3.000000    0.861667    0.840896    0.972500    0.507463
#
#             casual   registered          cnt
# count   731.000000   731.000000   731.000000
# mean    848.176471  3656.172367  4504.348837
# std     686.622488  1560.256377  1937.211452
# min       2.000000    20.000000    22.000000
# 25%     315.500000  2497.000000  3152.000000
# 50%     713.000000  3662.000000  4548.000000
# 75%    1096.000000  4776.500000  5956.000000
# max    3410.000000  6946.000000  8714.000000

# %%
print dataset.columns
# Out:
# Index([u'instant', u'dteday', u'season', u'yr', u'mnth', u'holiday',
#        u'weekday', u'workingday', u'weathersit', u'temp', u'atemp', u'hum',
#        u'windspeed', u'casual', u'registered', u'cnt'],
#       dtype='object')

# %% [markdown]
# There are some variables correlated with the time as:
#
# -  'dteday'
# - 'season'
# - 'yr'
# - 'mnth'
# - 'holiday'
# - 'weekday' or 'workingday'
#
# There are some weather variables:
#
# - 'weathersit'-
# - 'temp'
# - 'atemp'
# - 'hum',
# - 'windspeed'
#
#
#
#
# The variable to predict is the count:
#
# - 'cnt': total count of users
# - 'casual' and 'registered' are the number of casual and registered users

# %%
dataset[['instant','dteday','season','yr','mnth','holiday','weekday', 'workingday','cnt']].head()
# Out:
#    instant      dteday  season  yr  mnth  holiday  weekday  workingday   cnt
# 0        1  2011-01-01       1   0     1        0        6           0   985
# 1        2  2011-01-02       1   0     1        0        0           0   801
# 2        3  2011-01-03       1   0     1        0        1           1  1349
# 3        4  2011-01-04       1   0     1        0        2           1  1562
# 4        5  2011-01-05       1   0     1        0        3           1  1600

# %%
dataset.plot('dteday','cnt')

# %%
'''
#simplest way to compute the correlation matrix
import matplotlib.pyplot as plt

plt.matshow(dataset.corr())
'''
#using seaborn

corr = dataset.corr()
plt.figure(figsize=(8,8))
sns.heatmap(corr,
            xticklabels=corr.columns.values,
            yticklabels=corr.columns.values)


# now I plot the correlations only with the count dropping the values which I see the highest correlations

plt.figure()

corr['cnt'].drop(['cnt','instant',u'casual', u'registered']).plot( kind='bar', title='Correlation with counts')

# %% [markdown]
# ### Drop some data correlated among them
# or not useful. The list is:
#
# ['instant',u'casual', u'registered', 'atemp']

# %%
print dataset.columns
new_dataset_df = dataset.drop(['dteday','yr','mnth','instant','atemp','casual', 'registered','cnt'], axis=1)
# Out:
# Index([u'instant', u'dteday', u'season', u'yr', u'mnth', u'holiday',
#        u'weekday', u'workingday', u'weathersit', u'temp', u'atemp', u'hum',
#        u'windspeed', u'casual', u'registered', u'cnt'],
#       dtype='object')

# %%
pd.plotting.scatter_matrix(new_dataset_df, figsize=(20,20))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x000000004095D668>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000000004083F9E8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000000040BE7DD8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000000040CAB240>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000000040CDD5F8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000000040D549E8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000000040E0DDD8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000000040ED3518>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x0000000040F07C88>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000000041522438>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000000041597BA8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000000004161A358>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x00000000416D2AC8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000000041757278>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x00000000417889E8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000000004180D198>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x0000000041881908>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x00000000419470B8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x00000000419BC828>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000000041A33F98>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000000041B0A748>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000000041B40EB8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000000041C03668>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000000040A74D30>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x0000000040A5D6A0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000000004063DFD0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x00000000406E1AC8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x00000000406D4550>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x00000000405A2E80>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000000003CAEB1D0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000000003CAFBB38>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000000003C85F160>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x000000003C5F9F28>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000000003C4763C8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000000003C350278>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000000003C22AAC8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000000003C857D30>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000000003C9C24E0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000000040A7CC50>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000000003C0A5400>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x000000003C0A4B70>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000000003C413320>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000000041CF0A90>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000000003C32E240>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000000003C81E9B0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000000040A3B160>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000000041D278D0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000000041D69080>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x0000000041D9B7F0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000000041E13F60>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000000041ED6710>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000000041F0DE80>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000000041FD0630>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000000042088DA0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x00000000420C7550>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x00000000420FBCC0>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x00000000421C2470>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000000042237BE0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x00000000422BC390>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x00000000423B5B00>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x00000000423F72B0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x00000000424EBA20>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000000004256F1D0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x00000000425E7940>]],
#       dtype=object)

# %%
corr = new_dataset_df.corr()
plt.figure(figsize=(8,8))
sns.heatmap(corr,
            xticklabels=corr.columns.values,
            yticklabels=corr.columns.values)
corr['hum']
# Out:
# season        0.205445
# holiday      -0.015937
# weekday      -0.052232
# workingday    0.024327
# weathersit    0.591045
# temp          0.126963
# hum           1.000000
# windspeed    -0.248489
# Name: hum, dtype: float64

# %% [markdown]
# - humidity is higly correlated with weathersit. _What I should do?_
# - Time variables correlated among them
# - casual and registered shouldn't be useful as prediction variables, also _registered_ is almost _count_
#
#
#
# ['yr','mnth','instant','atemp','casual', 'registered','cnt']

# %% [markdown]
# # Applying models
#
# Now that I have dropped several columns that are corelated among them, I will try to do predictions with the remaining data. The fact that all there are 8 variables doesn't mean all must be used.

# %% [markdown]
# The usable data is added to the dataframe *bikes_df* and there are variables to perform the prediction +  the variable to predict

# %%
bikes_df = new_dataset_df
bikes_df['cnt'] =dataset['cnt']
bikes_df['instant'] = dataset['instant']

# %%
print 'Are there  nan values? '+ str(bikes_df.isnull().values.any())
# Out:
# Are there  nan values? False

# %%
bikes_df.head(8)
# Out:
#    season  holiday  weekday  workingday  weathersit      temp       hum  \
# 0       1        0        6           0           2  0.344167  0.805833
# 1       1        0        0           0           2  0.363478  0.696087
# 2       1        0        1           1           1  0.196364  0.437273
# 3       1        0        2           1           1  0.200000  0.590435
# 4       1        0        3           1           1  0.226957  0.436957
# 5       1        0        4           1           1  0.204348  0.518261
# 6       1        0        5           1           2  0.196522  0.498696
# 7       1        0        6           0           2  0.165000  0.535833
#
#    windspeed   cnt  instant
# 0   0.160446   985        1
# 1   0.248539   801        2
# 2   0.248309  1349        3
# 3   0.160296  1562        4
# 4   0.186900  1600        5
# 5   0.089565  1606        6
# 6   0.168726  1510        7
# 7   0.266804   959        8

# %% [markdown]
# **weekday info**: the day **0** is Sunday, so weekends are weekday={0,6}
# The data sets starts the _2011-01-01_

# %% [markdown]
# ### Split the data
#
# Split the data between train and test data

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(
    bikes_df.drop('cnt',axis=1), bikes_df['cnt'], test_size=0.33, random_state=42)

# %%
len(X_train), len(X_test)
# Out:
# (489, 242)

# %% [markdown]
# ### Lineal model
#
# Comment: No outlayers work

# %%
from sklearn import linear_model

# %%
# Create linear regression object
regr = linear_model.LinearRegression()

# Train the model using the training sets
regr.fit(X_train.drop('instant', axis=1), y_train)

# The coefficients
print('Coefficients: \n', regr.coef_)
# The mean squared error
print("Mean squared error: %.2f"
      % np.mean((regr.predict(X_test.drop('instant', axis=1)) - y_test) ** 2))
# Explained variance score: 1 is perfect prediction
print('Variance score: %.2f' % regr.score(X_test.drop('instant', axis=1), y_test))
# Out:
# ('Coefficients: \n', array([  397.97217605,  -408.5273323 ,    52.60922888,    23.11778199,
#         -499.39608954,  5695.14414771, -2056.29266223, -2914.175639  ]))
# Mean squared error: 1856178.37
# Variance score: 0.52

# %%
plt.figure(figsize=(10,7))
plt.plot(dataset['instant'],dataset['cnt'])
plt.plot(X_test['instant'],regr.predict(X_test.drop('instant', axis=1)), '.', label='test')
plt.plot(X_train['instant'],regr.predict(X_train.drop('instant', axis=1)), '.', label='train')
plt.legend()

# %% [markdown]
# ### SVM prediction

# %%
from sklearn import svm

# %%
clf = svm.SVR()
# train the model
clf.fit(X_train.drop('instant',axis=1), y_train)
# Out:
# SVR(C=1.0, cache_size=200, coef0=0.0, degree=3, epsilon=0.1,
#   gamma='auto_deprecated', kernel='rbf', max_iter=-1, shrinking=True,
#   tol=0.001, verbose=False)

# %%
# The coefficients
#print('Coefficients: \n', clf.coef_)
# The mean squared error
print("Mean squared error: %.2f"
      % np.mean((clf.predict(X_test.drop('instant', axis=1)) - y_test) ** 2))
# Explained variance score: 1 is perfect prediction
print('Variance score: %.2f' % clf.score(X_test.drop('instant', axis=1), y_test))
# Out:
# Mean squared error: 3882348.06
# Variance score: 0.00

# %%
plt.figure(figsize=(10,7))
plt.plot(dataset['instant'],dataset['cnt'])
plt.plot(X_test['instant'],clf.predict(X_test.drop('instant', axis=1)), '.', label='test')
plt.plot(X_train['instant'],clf.predict(X_train.drop('instant', axis=1)), '.', label='train')
plt.legend()

# %% [markdown]
# # Regresion tree

# %%
from sklearn.tree import DecisionTreeRegressor
from sklearn.model_selection import cross_val_score

# %%
tree = DecisionTreeRegressor(random_state=42)

# %%
X_train_d=X_train.drop('instant',axis=1)
X_test_d=X_test.drop('instant',axis=1)

# %%
cross_val_score(tree, (X_train), y_train, cv=10)
# Out:
# array([0.77942167, 0.79877491, 0.81856713, 0.68566556, 0.79707423,
#        0.82146014, 0.44621219, 0.73439684, 0.77662304, 0.75552876])

# %%
X_train_d.head()#
# Out:
#      season  holiday  weekday  workingday  weathersit      temp       hum  \
# 670       4        0        4           1           2  0.365833  0.581667
# 677       4        0        4           1           1  0.352174  0.333478
# 590       3        0        1           1           1  0.720833  0.545417
# 547       3        0        0           0           1  0.815833  0.518750
# 420       1        0        6           0           1  0.290833  0.395833
#
#      windspeed
# 670   0.157346
# 677   0.347835
# 590   0.136212
# 547   0.168529
# 420   0.421642

# %%
tree.fit(X_train,y_train)
# Out:
# DecisionTreeRegressor(criterion='mse', max_depth=None, max_features=None,
#            max_leaf_nodes=None, min_impurity_decrease=0.0,
#            min_impurity_split=None, min_samples_leaf=1,
#            min_samples_split=2, min_weight_fraction_leaf=0.0,
#            presort=False, random_state=42, splitter='best')

# %%
# The mean squared error
print("Mean squared error: %.2f"
      % np.mean((tree.predict(X_test) - y_test) ** 2))
# Explained variance score: 1 is perfect prediction
print('Variance score: %.2f' % tree.score(X_test, y_test))
# Out:
# Mean squared error: 677076.98
# Variance score: 0.83

# %%
plt.figure(figsize=(10,7))
plt.plot(dataset['instant'],dataset['cnt'])
plt.plot(X_test['instant'],tree.predict(X_test), '.', label='test')
plt.plot(X_train['instant'],tree.predict(X_train), '.', label='train')
plt.legend()

# %% [markdown]
# Com es que tinc que utilizzar el 'instant' per que fassi una predicció optima?!?!
# Pot ser que al utilizzar l'index apren a differenciar entre el primer i el segon any en els quals hi ha un augment??

# %%
export_graphviz(tree, out_file=None,
     feature_names=X_test.columns, class_names=['0', '1', '2'] ,
     filled = True)
# Out:
# 'digraph Tree {\nnode [shape=box, style="filled", color="black"] ;\n0 [label="instant <= 431.5\\nmse = 3670073.331\\nsamples = 489\\nvalue = 4553.239", fillcolor="#e581397f"] ;\n1 [label="instant <= 106.5\\nmse = 1763413.387\\nsamples = 283\\nvalue = 3477.071", fillcolor="#e581395e"] ;\n0 -> 1 [labeldistance=2.5, labelangle=45, headlabel="True"] ;\n2 [label="instant <= 70.5\\nmse = 513977.213\\nsamples = 64\\nvalue = 1722.422", fillcolor="#e5813928"] ;\n1 -> 2 ;\n3 [label="temp <= 0.422\\nmse = 274201.725\\nsamples = 45\\nvalue = 1431.911", fillcolor="#e581391f"] ;\n2 -> 3 ;\n4 [label="instant <= 31.0\\nmse = 206184.428\\nsamples = 43\\nvalue = 1372.884", fillcolor="#e581391d"] ;\n3 -> 4 ;\n5 [label="hum <= 0.67\\nmse = 136610.107\\nsamples = 22\\nvalue = 1157.273", fillcolor="#e5813916"] ;\n4 -> 5 ;\n6 [label="workingday <= 0.5\\nmse = 82556.996\\nsamples = 16\\nvalue = 1305.438", fillcolor="#e581391b"] ;\n5 -> 6 ;\n7 [label="temp <= 0.186\\nmse = 18363.959\\nsamples = 7\\nvalue = 1048.429", fillcolor="#e5813913"] ;\n6 -> 7 ;\n8 [label="windspeed <= 0.304\\nmse = 5277.688\\nsamples = 4\\nvalue = 947.25", fillcolor="#e5813910"] ;\n7 -> 8 ;\n9 [label="temp <= 0.136\\nmse = 64.667\\nsamples = 3\\nvalue = 989.0", fillcolor="#e5813911"] ;\n8 -> 9 ;\n10 [label="weekday <= 3.0\\nmse = 6.25\\nsamples = 2\\nvalue = 983.5", fillcolor="#e5813911"] ;\n9 -> 10 ;\n11 [label="mse = 0.0\\nsamples = 1\\nvalue = 986.0", fillcolor="#e5813911"] ;\n10 -> 11 ;\n12 [label="mse = 0.0\\nsamples = 1\\nvalue = 981.0", fillcolor="#e5813911"] ;\n10 -> 12 ;\n13 [label="mse = 0.0\\nsamples = 1\\nvalue = 1000.0", fillcolor="#e5813912"] ;\n9 -> 13 ;\n14 [label="mse = 0.0\\nsamples = 1\\nvalue = 822.0", fillcolor="#e581390c"] ;\n8 -> 14 ;\n15 [label="instant <= 22.5\\nmse = 3963.556\\nsamples = 3\\nvalue = 1183.333", fillcolor="#e5813917"] ;\n7 -> 15 ;\n16 [label="instant <= 15.5\\nmse = 484.0\\nsamples = 2\\nvalue = 1226.0", fillcolor="#e5813918"] ;\n15 -> 16 ;\n17 [label="mse = 0.0\\nsamples = 1\\nvalue = 1248.0", fillcolor="#e5813919"] ;\n16 -> 17 ;\n18 [label="mse = 0.0\\nsamples = 1\\nvalue = 1204.0", fillcolor="#e5813918"] ;\n16 -> 18 ;\n19 [label="mse = 0.0\\nsamples = 1\\nvalue = 1098.0", fillcolor="#e5813915"] ;\n15 -> 19 ;\n20 [label="temp <= 0.175\\nmse = 41151.556\\nsamples = 9\\nvalue = 1505.333", fillcolor="#e5813921"] ;\n6 -> 20 ;\n21 [label="windspeed <= 0.303\\nmse = 10584.25\\nsamples = 4\\nvalue = 1327.5", fillcolor="#e581391c"] ;\n20 -> 21 ;\n22 [label="temp <= 0.156\\nmse = 1938.889\\nsamples = 3\\nvalue = 1382.667", fillcolor="#e581391d"] ;\n21 -> 22 ;\n23 [label="mse = 0.0\\nsamples = 1\\nvalue = 1321.0", fillcolor="#e581391b"] ;\n22 -> 23 ;\n24 [label="temp <= 0.163\\nmse = 56.25\\nsamples = 2\\nvalue = 1413.5", fillcolor="#e581391e"] ;\n22 -> 24 ;\n25 [label="mse = 0.0\\nsamples = 1\\nvalue = 1421.0", fillcolor="#e581391e"] ;\n24 -> 25 ;\n26 [label="mse = 0.0\\nsamples = 1\\nvalue = 1406.0", fillcolor="#e581391e"] ;\n24 -> 26 ;\n27 [label="mse = 0.0\\nsamples = 1\\nvalue = 1162.0", fillcolor="#e5813917"] ;\n21 -> 27 ;\n28 [label="temp <= 0.244\\nmse = 20065.84\\nsamples = 5\\nvalue = 1647.6", fillcolor="#e5813925"] ;\n20 -> 28 ;\n29 [label="temp <= 0.202\\nmse = 687.188\\nsamples = 4\\nvalue = 1577.75", fillcolor="#e5813923"] ;\n28 -> 29 ;\n30 [label="windspeed <= 0.257\\nmse = 90.25\\nsamples = 2\\nvalue = 1552.5", fillcolor="#e5813923"] ;\n29 -> 30 ;\n31 [label="mse = 0.0\\nsamples = 1\\nvalue = 1562.0", fillcolor="#e5813923"] ;\n30 -> 31 ;\n32 [label="mse = 0.0\\nsamples = 1\\nvalue = 1543.0", fillcolor="#e5813922"] ;\n30 -> 32 ;\n33 [label="windspeed <= 0.138\\nmse = 9.0\\nsamples = 2\\nvalue = 1603.0", fillcolor="#e5813924"] ;\n29 -> 33 ;\n34 [label="mse = 0.0\\nsamples = 1\\nvalue = 1606.0", fillcolor="#e5813924"] ;\n33 -> 34 ;\n35 [label="mse = 0.0\\nsamples = 1\\nvalue = 1600.0", fillcolor="#e5813924"] ;\n33 -> 35 ;\n36 [label="mse = 0.0\\nsamples = 1\\nvalue = 1927.0", fillcolor="#e581392e"] ;\n28 -> 36 ;\n37 [label="weekday  ...

# %%
from sklearn.externals.six import StringIO  
from sklearn.tree import export_graphviz
import pydotplus
from IPython.display import Image  
from graphviz import Source

dot_data = StringIO()

graph = Source(export_graphviz(tree, out_file=None,
     feature_names=labels, class_names=['0', '1', '2'] ,
     filled = True))
display(SVG(graph.pipe(format='svg')))
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-273-decaeeedc856> in <module>()
#       3 import pydotplus
#       4 from IPython.display import Image
# ----> 5 from graphviz import Source
#       6
#       7 dot_data = StringIO()
#
# ImportError: No module named graphviz

# %%
tree.tree_

# %% [markdown]
# ## Tree model with sklearn
#
# Using an example from the web

# %%
dataset = pd.read_csv("day.csv",usecols=['season','holiday','weekday','workingday','weathersit','cnt'])
dataset.sample(frac=1).head()
# Out:
#      season  holiday  weekday  workingday  weathersit   cnt
# 415       1        1        1           0           1  3129
# 186       3        0        3           1           1  4629
# 142       2        0        1           1           2  4274
# 723       1        0        1           1           2   920
# 640       4        0        2           1           3  4639

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 731 entries, 0 to 730
# Data columns (total 6 columns):
# season        731 non-null int64
# holiday       731 non-null int64
# weekday       731 non-null int64
# workingday    731 non-null int64
# weathersit    731 non-null int64
# cnt           731 non-null int64
# dtypes: int64(6)
# memory usage: 34.3 KB

# %%
#Import the regression tree model
from sklearn.tree import DecisionTreeRegressor
#Parametrize the model
#We will use the mean squered error == varince as spliting criteria and set the minimum number
#of instances per leaf = 5
regression_model = DecisionTreeRegressor(criterion="mse",min_samples_leaf=5)

# %%
"""
Create a training as well as a testing set
"""
def train_test_split(dataset):
    training_data = dataset.iloc[:int(0.7*len(dataset))].reset_index(drop=True)#We drop the index respectively relabel the index
    #starting form 0, because we do not want to run into errors regarding the row labels / indexes
    testing_data = dataset.iloc[int(0.7*len(dataset)):].reset_index(drop=True)
    return training_data,testing_data
training_data = train_test_split(dataset)[0]
testing_data = train_test_split(dataset)[1]

# %%
#Fit the model
regression_model.fit(training_data.iloc[:,:-1],training_data.iloc[:,-1:])
#Predict unseen query instances
predicted = regression_model.predict(testing_data.iloc[:,:-1])
#Compute and plot the RMSE
RMSE = np.sqrt(np.sum(((testing_data.iloc[:,-1]-predicted)**2)/len(testing_data.iloc[:,-1])))
RMSE
# Out:
# 2360.6966567203835

# %%
"""
Plot the RMSE with respect to the minimum number of instances
""" 

fig = plt.figure()
ax0 = fig.add_subplot(111) 
RMSE_train = []
RMSE_test = []
n_instances = 100
for i in range(1,n_instances):
    #Paramterize the model and let i be the number of minimum instances per leaf node
    regression_model = DecisionTreeRegressor(criterion="mse",min_samples_leaf=i)   
    #Train the model
    regression_model.fit(training_data.iloc[:,:-1],training_data.iloc[:,-1:])
    #Predict query instances
    predicted_train = regression_model.predict(training_data.iloc[:,:-1])
    predicted_test = regression_model.predict(testing_data.iloc[:,:-1])
    #Calculate and append the RMSEs
    RMSE_train.append(np.sqrt(np.sum(((training_data.iloc[:,-1]-predicted_train)**2)/len(training_data.iloc[:,-1]))))
    RMSE_test.append(np.sqrt(np.sum(((testing_data.iloc[:,-1]-predicted_test)**2)/len(testing_data.iloc[:,-1]))))
   
ax0.plot(range(1,n_instances),RMSE_test,label='Test_Data')
ax0.plot(range(1,n_instances),RMSE_train,label='Train_Data')
ax0.legend()
ax0.set_title('RMSE with respect to the minumim number of instances per node')
ax0.set_xlabel('#Instances')
ax0.set_ylabel('RMSE')
plt.show()

# %%
from sklearn.model_selection import train_test_split

# split data

X_train, X_test, y_train, y_test = train_test_split(
    testing_data.iloc[:,:-1], testing_data.iloc[:,-1:], test_size=0.33, random_state=42)

# %%
#Fit the model
regression_model.fit(X_train,y_train)
#Predict unseen query instances
predicted = regression_model.predict(X_test)

# %%
#Compute RMSE
def RMSE(y_test, predicted):
    sm = np.sum(([float(i[0]) for i in y_test.values]-predicted)**2)
    #print sm, y_test.values[30][0], predicted[30],y_test.values[30][0]- predicted[30]
    RMSE = np.sqrt((sm)/float(len(y_test)))
    return RMSE

# %%
"""
Plot the RMSE with respect to the minimum number of instances
""" 

fig = plt.figure()
ax0 = fig.add_subplot(111) 
RMSE_train = []
RMSE_test = []
n_instances = 150
for i in range(1,n_instances):
    #Paramterize the model and let i be the number of minimum instances per leaf node
    regression_model = DecisionTreeRegressor(criterion="mse",min_samples_leaf=i)   
    #Train the model
    regression_model.fit(X_train,y_train)
    #Predict query instances
    predicted_train = regression_model.predict(X_train)
    predicted_test = regression_model.predict(X_test)
    #Calculate and append the RMSEs
    RMSE_train.append( RMSE(y_train, predicted_train))
    RMSE_test.append(RMSE(y_test, predicted_test))
   
ax0.plot(range(1,n_instances),RMSE_test,label='Test_Data')
ax0.plot(range(1,n_instances),RMSE_train,label='Train_Data')
ax0.legend()
ax0.set_title('RMSE with respect to the minumim number of instances per node')
ax0.set_xlabel('#Instances')
ax0.set_ylabel('RMSE')
plt.show()
